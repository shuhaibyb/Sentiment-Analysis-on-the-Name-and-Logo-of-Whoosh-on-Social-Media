# %%
import pandas as pd

# %%
df1 = pd.read_csv('/content/data_1.csv')
df2 = pd.read_csv('/content/data_2.csv')
df3 = pd.read_csv('/content/data_3.csv')
df4 = pd.read_csv('/content/data_4.csv')
df5 = pd.read_csv('/content/data_5.csv')
df6 = pd.read_csv('/content/data_6.csv')
df7 = pd.read_csv('/content/data_7.csv')
df8 = pd.read_csv('/content/data_8.csv')
df9 = pd.read_csv('/content/data_9.csv')
df10 = pd.read_csv('/content/data_10.csv')
df11 = pd.read_csv('/content/data_11.csv')
df12 = pd.read_csv('/content/data_12.csv')
df13 = pd.read_csv('/content/data_13.csv')
df14 = pd.read_csv('/content/data_14.csv')
df15 = pd.read_csv('/content/data_15.csv')
df16 = pd.read_csv('/content/data_16.csv')
df17 = pd.read_csv('/content/data_17.csv')
df18 = pd.read_csv('/content/data_18.csv')
df19 = pd.read_csv('/content/data_19.csv')
df20 = pd.read_csv('/content/data_20.csv')
df21 = pd.read_csv('/content/data_21.csv')
df22 = pd.read_csv('/content/data_22.csv')
df23 = pd.read_csv('/content/data_23.csv')
df24 = pd.read_csv('/content/data_24.csv')
df25 = pd.read_csv('/content/data_25.csv')
df26 = pd.read_csv('/content/data_26.csv')
df27 = pd.read_csv('/content/data_27.csv')
df28 = pd.read_csv('/content/data_28.csv')
df29 = pd.read_csv('/content/data_29.csv')
df30 = pd.read_csv('/content/data_30.csv')
df31 = pd.read_csv('/content/data_31.csv')
df32 = pd.read_csv('/content/data_32.csv')
df33 = pd.read_csv('/content/data_33.csv')
df34 = pd.read_csv('/content/data_34.csv')
df35 = pd.read_csv('/content/data_35.csv')
df36 = pd.read_csv('/content/data_36.csv')
df37 = pd.read_csv('/content/data_37.csv')
df38 = pd.read_csv('/content/data_38.csv')
df39 = pd.read_csv('/content/data_39.csv')
df40 = pd.read_csv('/content/data_40.csv')

# %%
combined_df = pd.concat([df1, df2, df3, df4, df5, df6, df7, df8, df9, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19, df20, df21, df22, df23, df24, df25, df26, df27, df28, df29, df30, df31, df32, df33, df34, df35, df36, df37, df38, df39, df40], ignore_index=True)

combined_df
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0     1708665234477740121  Mon Oct 02 02:14:26 +0000 2023              20
# 1     1708665234477740121  Sat May 11 03:58:07 +0000 2024               0
# 2     1708665234477740121  Sat May 11 04:00:14 +0000 2024               0
# 3     1708665234477740121  Sat May 11 04:05:23 +0000 2024               0
# 4     1708665234477740121  Mon Oct 02 10:49:06 +0000 2023               0
# ...                   ...                             ...             ...
# 4820  1708665234477740121  Mon Oct 02 09:34:52 +0000 2023               4
# 4821  1708665234477740121  Sun May 12 06:43:23 +0000 2024               0
# 4822  1708665234477740121  Mon Oct 02 03:25:17 +0000 2023               7
# 4823  1708665234477740121  Mon Oct 02 14:01:58 +0000 2023               0
# 4824  1708665234477740121  Mon Oct 02 15:43:54 +0000 2023               0
#
#                                               full_text               id_str  \
# ...

# %%
combined_df = combined_df.drop_duplicates()

# %%
combined_df
# Out:
#       conversation_id_str                      created_at  favorite_count  \
# 0     1708665234477740121  Mon Oct 02 02:14:26 +0000 2023              20
# 1     1708665234477740121  Sat May 11 03:58:07 +0000 2024               0
# 2     1708665234477740121  Sat May 11 04:00:14 +0000 2024               0
# 3     1708665234477740121  Sat May 11 04:05:23 +0000 2024               0
# 4     1708665234477740121  Mon Oct 02 10:49:06 +0000 2023               0
# ...                   ...                             ...             ...
# 1748  1708665234477740121  Mon Oct 02 09:35:08 +0000 2023               0
# 1754  1708665234477740121  Mon Oct 02 05:16:47 +0000 2023               0
# 2300  1708665234477740121  Mon Oct 02 16:14:47 +0000 2023               0
# 2725  1708665234477740121  Tue Oct 03 01:56:44 +0000 2023               0
# 4786  1708665234477740121  Mon Oct 02 06:55:30 +0000 2023               1
#
#                                               full_text               id_str  \
# ...

# %%
combined_df.to_excel('/content/combined_data_twitter.xlsx', index=False)
